# %% [markdown]
# # 01. Matplotlib 기초
# ---
# - Matplotlib는 Python에서 데이터 시각화를 위한 가장 널리 사용되는 라이브러리이다. <br>
#     특히 다양한 형태의 그래프와 차트를 생성하여 데이터를 효과적으로 표현할 수 있다.
#
# Matplotlib는 잘 정리된 공식 문서를 제공한다.
# [Matplotlib Documentation](https://matplotlib.org/stable/index.html)
#
# - **Matplotlib의 특장점**
#     - 선 그래프, 막대 그래프, 산점도, 히스토그램 등 다양한 시각화 유형을 지원한다.
#     - Pandas, NumPy 등 다른 데이터 분석 라이브러리와 쉽게 연동 가능하다.
#     - 그래프의 색상, 선 스타일, 마커 등을 세밀하게 커스터마이징 할 수 있다.
#     - Jupyter Notebook 환경에서 인터랙티브하게 사용 가능하다.

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp312-cp312-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\wia\miniforge3\envs\helloworld\lib\site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\wia\miniforge3\envs\helloworld\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\wia\miniforge3\envs\helloworld\lib\site-packages (from matplotlib) (11.3.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wia\miniforge3\envs\helloworld\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\wia\miniforge3\envs\helloworld\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------------------------- ------- 6.6/8.1 MB 33.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 29.7 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 21.3 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/6 [pyparsing]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    -------------------- ------------------- 3/6 [cycler]
#    -------------------------- ------------- 4/6 [contourpy]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    ---------------------------------------- 6/6 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pyparsing-3.2.5
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Matplotlib 기본 사용법
# ### pyplot 모듈
#
#  > Matplotlib의 pyplot 모듈은 MATLAB과 유사한 인터페이스를 제공한다.
#  > - plt.plot(): 선 그래프를 그리는 함수
#  > - plt.show(): 그래프를 화면에 표시하는 함수

# %%
# 일반적인 matplotlib 사용 방법
import matplotlib.pyplot as plt

# %% [markdown]
# ### 첫 번째 그래프 그리기
# - 가장 기본적인 선 그래프(Line Graph)를 그려보기.
#     - plot() 함수는 꺾은선 그래프 객체를 반환한다.
#     - Jupyter Notebook에서는 자동으로 그래프가 표시된다.

# %%
x = [1, 2, 3]
y = [2, 4, 8]

plt.plot(x,y)
# Out:
# [<matplotlib.lines.Line2D object at 0x000001AC0DD9EAE0>]

# %% [markdown]
# - plt.show()를 사용하면 그래프만 깔끔하게 표시된다.

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### 그래프 제목 설정
# - plt.title() 함수를 사용하여 그래프에 제목을 추가할 수 있다.

# %%
plt.plot(x,y)
plt.title('선그래프')
plt.show()
# Out:
# c:\Users\WIA\miniforge3\envs\helloworld\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\WIA\miniforge3\envs\helloworld\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\WIA\miniforge3\envs\helloworld\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\WIA\miniforge3\envs\helloworld\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정
# ### 한글 깨짐 문제 해결
# - Matplotlib의 기본 폰트는 한글을 지원하지 않아 한글이 깨져 보인다.
# - rcParams를 사용하여 한글 폰트를 설정해야 한다.

# %%
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 맑은고딕

# %%
plt.plot(x,y)
plt.title('선그래프')
plt.show()

# %% [markdown]
# ### 사용 가능한 폰트 목록 확인
# - 시스템에 설치된 폰트 목록을 확인하여 사용 가능한 한글 폰트를 찾을 수 있다.

# %%
import matplotlib.font_manager as fm

# fm.fontManager.ttflist

[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'cmr10',
#  'cmb10',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmsy10',
#  'cmss10',
#  'DejaVu Sans',
#  'cmtt10',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'cmmi10',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'cmex10',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'STIXGeneral',
#  'Arial Rounded MT Bold',
#  'Ravie',
#  'Candara',
#  'Romantic',
#  'Trebuchet MS',
#  'Goudy Old Style',
#  'SansSerif',
#  'Swis721 LtCn BT',
#  'Poor Richard',
#  'SymbolProp BT',
#  'Kristen ITC',
#  'Simplex',
#  'High Tower Text',
#  'Comic Sans MS',
#  'Bodoni MT',
#  'Calibri',
#  'Chiller',
#  'Franklin Gothic Book',
#  'Haettenschweiler',
#  'Gill Sans Ultra Bold Condensed',
#  'Sitka Small',
#  'Perpetua',
#  'Bodoni MT',
#  'Swis721 Ex BT',
#  'HYGraphic-Medium',
#  'Gadugi',
#  'SAPDings',
#  'SAPIcons',
#  'Lucida Sans Typewriter',
#  'Malgun Gothic',
#  'AcadEref',
#  'Franklin Gothic Heavy',
#  'Tw Cen MT',
#  'Tw Cen MT',
#  'Felix Titling',
#  'RomanS',
#  'Colonna MT',
#  'Bookman Old Style',
#  'Imprint MT Shadow',
#  'ISOCP',
#  'Bodoni MT',
#  'Monospac821 BT',
#  'HYSinMyeongJo-Medium',
#  'HYMyeongJo-Extra',
#  'Lucida Sans Typewriter',
#  'Lucida Sans',
#  'Lucida Bright',
#  'Consolas',
#  'Microsoft Sans Serif',
#  'Segoe UI Symbol',
#  'Symusic',
#  'Rockwell',
#  'Century Schoolbook',
#  'Arial',
#  'MoeumT R',
#  'Siemens AD VN',
#  'CityBlueprint',
#  'Yu Gothic',
#  'Eras Medium ITC',
#  'HYHeadLine-Medium',
#  'Arial',
#  'Microsoft JhengHei',
#  'ISOCT3',
#  'HDharmony',
#  'Swis721 Blk BT',
#  'Bodoni MT',
#  'MS Reference Specialty',
#  'Bodoni MT',
#  'Century Gothic',
#  'Cooper Black',
#  'Segoe Script',
#  'Cambria',
#  'Papyrus',
#  'Swis721 Cn BT',
#  'GreekC',
#  'Pyunji R',
#  'SymbolMono BT',
#  'Webdings',
#  'Monotxt',
#  'ISOCTEUR',
#  'Gabriola',
#  'Rage Italic',
#  '72',
#  'HYGothic-Medium',
#  'Lucida Fax',
#  'Corbel',
#  'Monospac821 BT',
#  'Simplex',
#  'SansSerif',
#  'Times New Roman',
#  'Segoe UI Historic',
#  'Wingdings 3',
#  'Bradley Hand ITC',
#  'Lucida Calligraphy',
#  'Proxy 1',
#  'Proxy 3',
#  'Californian FB',
#  'Segoe UI',
#  'Kunstler Script',
#  'Malgun Gothic',
#  'Verdana',
#  'Book Antiqua',
#  'Swis721 Cn BT',
#  'Swis721 BT',
#  'Tahoma',
#  'Mongolian Baiti',
#  'Nirmala UI',
#  'Leelawadee UI',
#  'Tw Cen MT Condensed',
#  'Proxy 5',
#  'Lucida Sans',
#  'Proxy 2',
#  'Century Schoolbook',
#  'Siemens AD KS',
#  'Wingdings',
#  'Comic Sans MS',
#  'Gill Sans MT Ext Condensed Bold',
#  'Microsoft Yi Baiti',
#  'HYPost-Medium',
#  'Magneto',
#  'Rockwell',
#  'HYPost-Light',
#  'SimSun-ExtB',
#  'Noto Sans KR',
#  'Microsoft YaHei',
#  '72',
#  'Gill Sans Ultra Bold',
#  'Curlz MT',
#  'Proxy 4',
#  'GreekS',
#  'Corbel',
#  'Segoe Print',
#  'AmdtSymbols',
#  'Complex',
#  'Swis721 BT',
#  'CommercialPi BT',
#  'SHeadG',
#  'Calibri',
#  'Bodoni MT',
#  'Consolas',
#  'SansSerif',
#  'Simplex',
#  'Syastro',
#  'New Gulim',
#  'Segoe UI',
#  'Segoe Print',
#  'Swis721 BlkCn BT',
#  'Symeteo',
#  'EuroRoman',
#  'Segoe UI',
#  'Constantia',
#  'Trebuchet MS',
#  'Yu Gothic',
#  '72',
#  'Segoe UI',
#  'HYShortSamul-Medium',
#  'Courier New',
#  'Gill Sans MT',
#  'MingLiU-ExtB',
#  'Monotype Corsiva',
#  'Perpetua Titling MT',
#  'Georgia',
#  'SAPGUI-Belize-Icons',
#  'Matura MT Script Capitals',
#  'Symbol',
#  'Segoe Script',
#  'Gill Sans MT',
#  'Siemens AD CH Traditional',
#  'ItalicT',
#  'Lucida Fax',
#  'Vineta BT',
#  'Swis721 BdCnOul BT',
#  'Agency FB',
#  'Candara',
#  'CountryBlueprint',
#  'Segoe UI',
#  'ItalicC',
#  'Copperplate Gothic Light',
#  'ScriptS',
#  'Microsoft YaHei',
#  'Georgia',
#  'Consolas',
#  'Elephant',
#  'Symeteo',
#  'MS Outlook',
#  'Calibri',
#  'Leelawadee UI',
#  'ISOCTEUR',
#  'Gloucester MT Extra Condensed',
#  'MS Reference Sans Serif',
#  'Bodoni MT',
#  'Rockwell',
#  'SuperFrench',
#  'Complex',
#  'IPAPGothic',
#  'GreekS',
#  'Berlin Sans FB',
#  'Verdana',
#  'Courier10 BT',
#  'Berlin Sans FB',
#  'SansSerif',
#  'GreekC',
#  'Corbel',
#  'HoloLens MDL2 Assets',
#  'Romantic',
#  'CommercialScript BT',
#  'SimSun',
#  'BankGothic Lt BT',
#  'Monospac821 BT',
#  'Tw Cen MT Condensed Extra Bold',
#  'EuroRoman',
#  'Swis721 Cn BT',
#  'Brush Script MT',
#  'Lucida Bright',
#  '72',
#  'Swis721 BlkCn BT',
#  'Italic',
#  'Microsoft Himalaya',
#  'Rockwell Extra Bold',
#  'Constantia',
#  'Vivaldi',
#  'Monotxt',
#  'ISOCT3',
#  'Trebuchet MS',
#  'Jokerman',
#  'Txt',
#  'Old English Text MT',
#  'Constantia',
#  'Rockwell Condensed',
#  'Century Gothic',
#  'Calisto MT',
#  'Arial',
#  'Sylfaen',
#  'Nirmala UI',
#  'Times New Roman',
#  '72',
#  'Blackadder ITC',
#  'Siemens AD TH',
#  'ISOCP3',
#  'Arial',
#  'Tw Cen MT Condensed',
#  'ISOCT',
#  'French Script MT',
#  'Palatino Linotype',
#  'Times New Roman',
#  'OCR A Extended',
#  'Niagara Engraved',
#  'Arial',
#  'AMGDT',
#  'Broadway',
#  'GreekC',
#  'Gadugi',
#  'ISOCP2',
#  'Cambria',
#  'Bookman Old Style',
#  'GreekS',
#  'Arial',
#  'Castellar',
#  'Cambria',
#  'Yu Gothic',
#  'Arial',
#  'Adobe Devanagari',
#  'Myanmar Text',
#  'Calibri',
#  'ISOCT',
#  'Juice ITC',
#  'Dutch801 XBd BT',
#  'Segoe MDL2 Assets',
#  'Adobe Devanagari',
#  'Courier10 BT',
#  'Impact',
#  'Tahoma',
#  'RomanC',
#  'Swis721 BlkEx BT',
#  'Segoe UI',
#  'Swis721 BT',
#  'Candara',
#  'Cambria',
#  'Harrington',
#  'Goudy Stout',
#  'Lucida Sans Typewriter',
#  'ScriptS',
#  'RomanS',
#  'Technic',
#  'Ebrima',
#  'Garamond',
#  'Bernard MT Condensed',
#  '72',
#  'Segoe UI',
#  'Microsoft New Tai Lue',
#  'Lucida Handwriting',
#  'Adobe Devanagari',
#  'Trebuchet MS',
#  'Leelawadee UI',
#  'AIGDT',
#  'Onyx',
#  'Goudy Old Style',
#  'Segoe UI',
#  'Agency FB',
#  'ScriptC',
#  'Californian FB',
#  'Bookshelf Symbol 7',
#  'Nirmala UI',
#  'ScriptS',
#  'Verdana',
#  'PanRoman',
#  'HDharmony',
#  'Dutch801 Rm BT',
#  'Headline R',
#  'Franklin Gothic Medium',
#  'Tw Cen MT',
#  'Syastro',
#  'Yet R',
#  'Parchment',
#  'Symath',
#  'Corbel',
#  'Stylus BT',
#  'Eras Bold ITC',
#  'Symap',
#  'Segoe UI',
#  'AMGDT_IV25',
#  'Bookman Old Style',
#  'Freestyle Script',
#  'Microsoft Tai Le',
#  'GothicE',
#  'Bell MT',
#  'ISOCT2',
#  'Txt',
#  'Swis721 Ex BT',
#  'RomanT',
#  'Snap ITC',
#  'Candara',
#  'Californian FB',
#  'Courier10 BT',
#  'Txt',
#  'Informal Roman',
#  'Comic Sans MS',
#  'Comic Sans MS',
#  'Bahnschrift',
#  'ISOCP3',
#  'Century',
#  'Perpetua',
#  'Corbel',
#  'Yu Gothic',
#  'Monospac821 BT',
#  'Lucida Console',
#  'Bauhaus 93',
#  'Siemens AD Mono VN',
#  'Forte',
#  'TechnicLite',
#  'Lucida Sans Unicode',
#  'Candara',
#  'MV Boli',
#  'Maiandra GD',
#  'Corbel',
#  'UniversalMath1 BT',
#  'Sitka Small',
#  'Symath',
#  'Century Schoolbook',
#  'Gill Sans MT',
#  'Symap',
#  'Proxy 9',
#  'IPAexGothic',
#  'Swis721 LtCn BT',
#  'Italic',
#  'Ebrima',
#  'Bodoni MT',
#  'Bookman Old Style',
#  'Eras Demi ITC',
#  'Syastro',
#  'Complex',
#  'Sitka Small',
#  'Garamond',
#  'Candara',
#  'Copperplate Gothic Bold',
#  'Georgia',
#  'Microsoft JhengHei',
#  'Wide Latin',
#  'Verdana',
#  'Symusic',
#  'Segoe UI',
#  'Gulim',
#  'Magic R',
#  'Consolas',
#  'Modern No. 20',
#  'ISOCPEUR',
#  'Proxy 6',
#  'Palatino Linotype',
#  'Symusic',
#  'Sitka Small',
#  'AMGDT_IV50',
#  'Microsoft Tai Le',
#  'Lucida Fax',
#  'HD LOGO',
#  'Swis721 BdOul BT',
#  'Microsoft PhagsPa',
#  'Microsoft New Tai Lue',
#  'GothicI',
#  '72',
#  'Swis721 BT',
#  'Algerian',
#  'Century Schoolbook',
#  'Symath',
#  'Proxy 7',
#  'HDharmony',
#  'Lucida Bright',
#  'Swis721 Lt BT',
#  'ISOCT2',
#  'CATIA Symbols',
#  'Swis721 BlkOul BT',
#  'Franklin Gothic Demi',
#  'Elephant',
#  'Book Antiqua',
#  'Wingdings 2',
#  'Lucida Sans Typewriter',
#  'Free 3 of 9',
#  'ISOCT3',
#  'Book Antiqua',
#  'Dutch801 Rm BT',
#  'Javanese Text',
#  'Segoe UI',
#  'Rockwell Condensed',
#  'Ink Free',
#  'GDT_IV50',
#  'ISOCT2',
#  'Courier New',
#  'Symeteo',
#  'Constantia',
#  'GOST Common',
#  'Stencil',
#  'Calibri',
#  'Gill Sans MT Condensed',
#  'Segoe UI',
#  'Calibri',
#  'Swis721 LtEx BT',
#  'Batang',
#  'Bodoni MT',
#  'Lucida Sans',
#  'Eras Light ITC',
#  'SAPGUI-Icons',
#  'RomanS',
#  'Courier10 BT',
#  'Bell MT',
#  'Garamond',
#  'Siemens AD Sans',
#  'Century Gothic',
#  'Calisto MT',
#  'Palatino Linotype',
#  'Siemens AD CH Simplified',
#  'ISOCPEUR',
#  'TechnicBold',
#  'Perpetua',
#  'Gigi',
#  'HYPMokGak-Bold',
#  'Footlight MT Light',
#  'Franklin Gothic Heavy',
#  'Calisto MT',
#  'ISOCP2',
#  'Franklin Gothic Demi Cond',
#  'Goudy Old Style',
#  'GENISO',
#  'Georgia',
#  'Century Gothic',
#  'Showcard Gothic',
#  'Bell MT',
#  'Microsoft YaHei',
#  'Swis721 Blk BT',
#  'Proxy 8',
#  'Mistral',
#  'GothicG',
#  'Bodoni MT',
#  'Baskerville Old Face',
#  'Calisto MT',
#  'Segoe UI Emoji',
#  'Siemens AD Mono',
#  'Pristina',
#  'Courier New',
#  'Franklin Gothic Demi',
#  'BankGothic Md BT',
#  'ISOCP',
#  'Rockwell',
#  'Palatino Linotype',
#  'Symap',
#  'HYGothic-Extra',
#  'ISOCT',
#  'Franklin Gothic Medium Cond',
#  'ISOCP3',
#  'Script MT Bold',
#  'Swis721 Lt BT',
#  'MS Gothic',
#  'Harlow Solid Italic',
#  'Adobe Devanagari',
#  'Times New Roman',
#  'Arial',
#  'Romantic',
#  'Viner Hand ITC',
#  'Microsoft PhagsPa',
#  'Lucida Sans',
#  'Niagara Solid',
#  'Courier New',
#  'Engravers MT',
#  'Ami R',
#  'Monotxt',
#  'Italic',
#  'Malgun Gothic',
#  'Siemens AD JP',
#  'Franklin Gothic Medium',
#  'Berlin Sans FB Demi',
#  'Dutch801 Rm BT',
#  'Microsoft JhengHei',
#  'Tw Cen MT',
#  'GDT_IV25',
#  'MT Extra',
#  'Britannic Bold',
#  'Book Antiqua',
#  'Perpetua',
#  'High Tower Text',
#  'Franklin Gothic Book',
#  'GOST Common',
#  'Gill Sans MT',
#  '72',
#  'Lucida Fax',
#  'Tempus Sans ITC',
#  'ISOCP',
#  'Edwardian Script ITC',
#  'Playbill',
#  'Arial',
#  'Perpetua Titling MT',
#  'SimSun-ExtG',
#  'Vladimir Script',
#  'Bodoni MT',
#  'Dutch801 Rm BT',
#  'Lucida Bright',
#  'RomanD',
#  'Swis721 Cn BT',
#  'Myanmar Text',
#  'GDT',
#  'Centaur',
#  'IPAGothic',
#  'Palace Script MT',
#  'HYGungSo-Bold',
#  'ISOCP2']

# %%
plt.rcParams['font.family'] = 'Gungsuh'  # 또는 '궁서'

# %%
plt.plot(x,y)
plt.title('선그래프')
plt.show()
# Out:
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# c:\Users\WIA\miniforge3\envs\helloworld\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\WIA\miniforge3\envs\helloworld\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\WIA\miniforge3\envs\helloworld\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\WIA\miniforge3\envs\helloworld\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.
# findfont: Font family 'Gungsuh' not found.

# %% [markdown]
# - 폰트명만 깔끔하게 보려면 리스트 컴프리헨션을 활용한다.

# %% [markdown]
# ### 한글 제목으로 그래프 그리기
# - 한글 폰트 설정 후 한글 제목을 사용할 수 있다.

# %% [markdown]
# ### 음수 값 표현하기
# - 음수 값도 정상적으로 표현되는지 확인해보자.
# - axes.unicode_minus 설정이 False여야 마이너스 기호가 깨지지 않는다.

# %%
import matplotlib

matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.size'] = 30

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
plt.title('음수값이 포함된 그래프')
plt.show()
