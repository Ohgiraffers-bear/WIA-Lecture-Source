# %% [markdown]
# Streamlit으로
#
# 맛집리스트들을 랜덤으로 뽑아 줄 수 있는 웹페이지
#
# 1. 현대위아 근처의 맛집
# 2. 랜덤으로 한집을 추천

# %%
# %pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    -------------------------------- ------- 8.1/10.1 MB 42.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 28.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 10.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------- ----------- 9.2/12.8 MB 43.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 36.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ----------------------------- ---------- 8.1/11.0 MB 41.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 34.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------  6.8/7.0 MB 42.0 MB/s eta 0:00:01
# ...
